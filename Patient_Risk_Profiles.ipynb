# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=FutureWarning)
from matplotlib import rcParams
rcParams["figure.figsize"] = 12, 6
sns.set_style('darkgrid')

# %%
df = pd.read_csv("Patient_Risk_Profiles.csv")
df.head()
df
# Out:
#     personId  age group:  10 -  14  age group:  15 -  19  \
# 0          1                     0                     0
# 1          2                     0                     0
# 2          3                     0                     0
# 3          4                     0                     0
# 4          5                     0                     0
# ..       ...                   ...                   ...
# 95        96                     0                     0
# 96        97                     0                     0
# 97        98                     0                     0
# 98        99                     0                     0
# 99       100                     0                     0
#
#     age group:  20 -  24  age group:  65 -  69  age group:  40 -  44  \
# 0                      0                     0                     0
# 1                      0                     0                     0
# 2                      0                     0                     0
# ...

# %%
df.drop_duplicates()
# Out:
#     personId  age group:  10 -  14  age group:  15 -  19  \
# 0          1                     0                     0
# 1          2                     0                     0
# 2          3                     0                     0
# 3          4                     0                     0
# 4          5                     0                     0
# ..       ...                   ...                   ...
# 95        96                     0                     0
# 96        97                     0                     0
# 97        98                     0                     0
# 98        99                     0                     0
# 99       100                     0                     0
#
#     age group:  20 -  24  age group:  65 -  69  age group:  40 -  44  \
# 0                      0                     0                     0
# 1                      0                     0                     0
# 2                      0                     0                     0
# ...

# %%
# Drop 'personId' column
df.drop(columns='personId', inplace=True)

# Drop columns starting with "Antibiotics" (case-insensitive)
df = df.loc[:, ~df.columns.str.strip().str.lower().str.startswith('antibiotics')]

# Drop specific columns in columns_to_drop. Dropping columns to isolate our intended data.
columns_to_drop = ['Acetaminophen exposures in prior year', 'Non-hemorrhagic Stroke in an inpatient setting in prior year',
                   'Aspirin exposures in prior year','STEROIDS in prior year','Occurrence of Anxiety in prior year','ANTIEPILEPTICS in prior year',
                   'Low back pain in prior year']
df.drop(columns=columns_to_drop, inplace=True)

df.columns
# Out:
# Index(['age group:  10 -  14', 'age group:  15 -  19', 'age group:  20 -  24',
#        'age group:  65 -  69', 'age group:  40 -  44', 'age group:  45 -  49',
#        'age group:  55 -  59', 'age group:  85 -  89', 'age group:  75 -  79',
#        'age group:   5 -   9', 'age group:  25 -  29', 'age group:   0 -   4',
#        'age group:  70 -  74', 'age group:  50 -  54', 'age group:  60 -  64',
#        'age group:  35 -  39', 'age group:  30 -  34', 'age group:  80 -  84',
#        'age group:  90 -  94', 'Sex = FEMALE', 'Sex = MALE',
#        'Occurrence of Alcoholism in prior year', 'Anemia in prior year',
#        'Angina events in prior year', 'Osteoarthritis in prior year',
#        'Occurrence of Asthma in prior year',
#        'Atrial Fibrillation, incident in prior year',
#        'HORMONAL CONTRACEPTIVES in prior year',
#        'Any cancer (excl. prostate cancer and benign cancer) in prior year',
#        'Acute Kidney Injury (AKI) in prior year',
# ...
