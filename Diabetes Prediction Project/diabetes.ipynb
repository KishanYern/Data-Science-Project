# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=FutureWarning)
from matplotlib import rcParams
rcParams["figure.figsize"] = 12, 6
sns.set_style('darkgrid')

# %% [markdown]
# # Importing Dataset

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# # Data Information

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# # Plotting data

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
sns.countplot(x='Outcome', data=df) # 0 = No diabetes, 1 = diabetes

plt.show()

# %%
sns.countplot(x='Outcome', hue='Pregnancies', data=df)

plt.show()

# %%
sns.histplot(x='Age', hue='Outcome', data=df)

plt.show()

# %% [markdown]
# A large proportion of the data seem to be under 30 years of age

# %%
sns.histplot(x='Glucose', hue='Outcome', data=df)

plt.show()

# %%
plt.pie(df['Outcome'].value_counts(), labels=['No Diabetes', 'Diabetes'], autopct='%1.1f%%', shadow=True, explode=[0, 0.1])

plt.show()

# %% [markdown]
# A majority of the data is patients with no diabeties

# %%
sns.pairplot(df, hue='Outcome', palette={0: 'blue', 1: 'red'}) # 0 = No diabetes, 1 = diabetes

plt.show()

# %%
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm') 
plt.title('Correlation between features')

plt.show()

# %% [markdown]
# There seems to be a relatively high relationship between glucose and outcome

# %%
plt.subplot(2, 2, 1)
sns.histplot(df['Glucose'], kde=True, color='skyblue')
plt.title('Histogram of Glucose')

plt.subplot(2, 2, 2)
sns.histplot(df['BloodPressure'], kde=True, color='salmon')
plt.title('Histogram of BloodPressure')

plt.subplot(2, 2, 3)
sns.histplot(df['BMI'], kde=True, color='green')
plt.title('Histogram of BMI')

plt.subplot(2, 2, 4)
sns.histplot(df['Insulin'], kde=True, color='purple')
plt.title('Histogram of Insulin')

plt.tight_layout()
plt.show()

# %%
sns.boxplot(data=df[['Glucose', 'BloodPressure', 'BMI', 'Insulin']], palette='Set1')
plt.title('Boxplot of Quantitative features')
plt.show()

# %% [markdown]
# Insulin seems to have many outliers

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Splitting Data

# %%
from sklearn.model_selection import train_test_split

X = df.drop('Outcome', axis=1)
y = df['Outcome']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
print(X)
print(X_train)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# ## Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
lr_y_pred = lr.predict(X_test)

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

lr_acc = accuracy_score(y_test, lr_y_pred)
lr_conf = confusion_matrix(y_test, lr_y_pred)
lr_class = classification_report(y_test, lr_y_pred)

print('Accuracy Score: ', lr_acc)
print('Confusion Matrix: \n', lr_conf)
print('Classification Report: \n', lr_class)
# Out:
# Accuracy Score:  0.7987012987012987
# Confusion Matrix:
#  [[89  7]
#  [24 34]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.93      0.85        96
#            1       0.83      0.59      0.69        58
#
#     accuracy                           0.80       154
#    macro avg       0.81      0.76      0.77       154
# weighted avg       0.80      0.80      0.79       154

# %% [markdown]
# ## Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_y_pred = dt.predict(X_test)

dt_acc = accuracy_score(y_test, dt_y_pred)
dt_conf = confusion_matrix(y_test, dt_y_pred)
dt_class = classification_report(y_test, dt_y_pred)

print('Accuracy Score: ', dt_acc)
print('Confusion Matrix: \n', dt_conf)
print('Classification Report: \n', dt_class)
# Out:
# Accuracy Score:  0.7402597402597403
# Confusion Matrix:
#  [[84 12]
#  [28 30]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.88      0.81        96
#            1       0.71      0.52      0.60        58
#
#     accuracy                           0.74       154
#    macro avg       0.73      0.70      0.70       154
# weighted avg       0.74      0.74      0.73       154

# %% [markdown]
# ## Random Forest Regression Model

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rf_y_pred = rf.predict(X_test)

rf_acc = accuracy_score(y_test, rf_y_pred)
rf_conf = confusion_matrix(y_test, rf_y_pred)
rf_class = classification_report(y_test, rf_y_pred)

print('Accuracy Score: ', rf_acc)
print('Confusion Matrix: \n', rf_conf)
print('Classification Report: \n', rf_class)
# Out:
# Accuracy Score:  0.7987012987012987
# Confusion Matrix:
#  [[87  9]
#  [22 36]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85        96
#            1       0.80      0.62      0.70        58
#
#     accuracy                           0.80       154
#    macro avg       0.80      0.76      0.77       154
# weighted avg       0.80      0.80      0.79       154
